# %% [markdown]
# <a href="https://colab.research.google.com/github/Thughandling/aithe_kody21c/blob/main/Compare_CTC_vs_Kenlm_results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
try:
  import editdistance
except:
  # !pip install editdistance
  import editdistance
from typing import List

# %%
#@title Run to setup Text Diff
import difflib
from typing import List, Any, Callable, Tuple, Union
from itertools import zip_longest
import html
import re

Token = str
TokenList = List[Token]

whitespace = re.compile('\s+')
end_sentence = re.compile('[.]\s+')

def tokenize(s:str) -> TokenList:
    '''Split a string into tokens'''
    return whitespace.split(s)

def untokenize(ts:TokenList) -> str:
    '''Join a list of tokens into a string'''
    return ' '.join(ts)

def sentencize(s:str) -> TokenList:
    '''Split a string into a list of sentences'''
    return end_sentence.split(s)

def unsentencise(ts:TokenList) -> str:
    '''Join a list of sentences into a string'''
    return '. '.join(ts)

def html_unsentencise(ts:TokenList) -> str:
    '''Joing a list of sentences into HTML for display'''
    return ''.join(f'<p>{t}</p>' for t in ts)

def mark_text(text:str) -> str:
    return f'<span style="color: red;">{text}</span>'
    
def mark_span(text:TokenList) -> TokenList:
    if len(text) > 0:
        text[0] = '<span style="background: #69E2FB;">' + text[0]
        text[-1] += '</span>'
    return text

def markup_diff(a:TokenList, b:TokenList,
                mark=mark_span,
                default_mark = lambda x: x,
                isjunk=None) -> Tuple[TokenList, TokenList]:
    """Returns a and b with any differences processed by mark

    Junk is ignored by the differ
    """
    seqmatcher = difflib.SequenceMatcher(isjunk=isjunk, a=a, b=b, autojunk=False)
    out_a, out_b = [], []
    for tag, a0, a1, b0, b1 in seqmatcher.get_opcodes():
        markup = default_mark if tag == 'equal' else mark
        out_a += markup(a[a0:a1])
        out_b += markup(b[b0:b1])
    assert len(out_a) == len(a)
    assert len(out_b) == len(b)
    return out_a, out_b


def align_seqs(a: TokenList, b: TokenList, fill:Token='') -> Tuple[TokenList, TokenList]:
    out_a, out_b = [], []
    seqmatcher = difflib.SequenceMatcher(a=a, b=b, autojunk=False)
    for tag, a0, a1, b0, b1 in seqmatcher.get_opcodes():
        delta = (a1 - a0) - (b1 - b0)
        out_a += a[a0:a1] + [fill] * max(-delta, 0)
        out_b += b[b0:b1] + [fill] * max(delta, 0)
    assert len(out_a) == len(out_b)
    return out_a, out_b


def html_sidebyside(a, b):
    # Set the panel display
    out = '<div style="display: grid;grid-template-columns: 1fr 1fr;grid-gap: 20px;">'
    # There's some CSS in Jupyter notebooks that makes the first pair unalign. This is a workaround
    out += '<p></p><p></p>'
    for left, right in zip_longest(a, b, fillvalue=''):
        out += f'<p>{left}</p>'
        out += f'<p>{right}</p>'
        out += '</div>'
    return out

def html_diffs(a, b):
    a = html.escape(a)
    b = html.escape(b)

    out_a, out_b = [], []
    for sent_a, sent_b in zip(*align_seqs(sentencize(a), sentencize(b))):
        mark_a, mark_b = markup_diff(tokenize(sent_a), tokenize(sent_b))
        out_a.append(untokenize(mark_a))
        out_b.append(untokenize(mark_b))

    return html_sidebyside(out_a, out_b)




def word_error_rate(hypotheses: List[str], references: List[str], use_cer=False) -> float:
    """
    Computes Average Word Error rate between two texts represented as
    corresponding lists of string. Hypotheses and references must have same
    length.
    Args:
      hypotheses: list of hypotheses
      references: list of references
      use_cer: bool, set True to enable cer
    Returns:
      (float) average word error rate
    """
    scores = 0
    words = 0
    if len(hypotheses) != len(references):
        raise ValueError(
            "In word error rate calculation, hypotheses and reference"
            " lists must have the same number of elements. But I got:"
            "{0} and {1} correspondingly".format(len(hypotheses), len(references))
        )
    for h, r in zip(hypotheses, references):
        if use_cer:
            h_list = list(h)
            r_list = list(r)
        else:
            h_list = h.split()
            r_list = r.split()
        words += len(r_list)
        scores += editdistance.eval(h_list, r_list)
    if words != 0:
        wer = 1.0 * scores / words
    else:
        wer = float('inf')
    return wer


def move_dimension_to_the_front(tensor, dim_index):
    all_dims = list(range(tensor.ndim))
    return tensor.permute(*([dim_index] + all_dims[:dim_index] + all_dims[dim_index + 1 :]))

# %%
from IPython.display import HTML

def show_diffs(a):
    display(HTML(html_diffs(a)))

# %%
import os

# %%
ctc_manifest_path = "/content/output_500.txt" #@param {type: "string"}
kenlm_manifest_path = "/content/kenlm_output_403.txt" #@param {type: "string"}
max_print_sample = 10 #@param {type:"integer"}


ctc_data = []
kenlm_data = []

with open(ctc_manifest_path, 'r', encoding='utf-8') as f:
  for line in f:
      data = json.loads(line)
      ctc_data.append(data)

with open(kenlm_manifest_path, 'r', encoding='utf-8') as f:
  for line in f:
      data = json.loads(line)
      kenlm_data.append(data)
 

if max_print_sample == 0:
  max_print_sample = len(kenlm_data)


print_sample_count = 0


for idx, ctc_item in enumerate(ctc_data):
  for idx2, kenlm_item in enumerate(kenlm_data):
    if os.path.split(ctc_item['audio_filepath'])[1] == os.path.split(kenlm_item['audio_filepath'])[1] :
      print("Audio : ",kenlm_item['audio_filepath'])
      print("CTC : ",ctc_item['pred_text'])
      print("Kenlm : ",kenlm_item['pred_text'])
      print("==============" * 3)

      print_sample_count += 1
    if print_sample_count > max_print_sample:
      break
# Out:
# Audio :  /data3/stt_dataset/metaM/stt_inference_input_kenlm/103-1678079539.2357_stereo_mono.wav
# CTC :  제가 변경한 와이줄리 이미지입니다 무엇을 도와드릴까요 네 그 택배 주문이 네 완료됐다고 하는데 알되는 상자에는 브레이드 하나밖에 안 들고 다른 상품이 하나도 안 들어있어요 근데 거기 배송 거기도 다 됐다고 나오고 우선 제가 한번 확인해볼게요 실례지가 고객님 성함이랑 연락처 번호가 어떻게 되실까요 정미경 정미경님 본인 맞으실까요 연락처번호 몇 번이세요 이 육 삼 이 오 오 칠 공 일 공 어 고객님 잠시만 기다려주시겠어요 네 고객님 정리용님 반갑습니다 혹시 이 월 이십 팔 일날 주문했던요 예 그럼 위아래 수금만 받으신 거예요 아니 브레이지 하나만 들었다니까요 브레이지와 위에 것만 하나겠어요 제가 해볼게요 그 잠시만 기다려주네요 아 네 고객님 기다려서 감사합니다 말씀하셨던 부분 저희가 확인해봤는데 너무 죄송스럽게도 고객님 주문할때 상품 중에 저희 사은품이 있으시잖아요 고객님 
# Kenlm :  안녕하세요 즐거운 경 아이 박태영입니다 무엇을 도와드릴까요 네 여보세요 말씀하세요 고객님 제가 구독 취소였는데 왜 결제가 되지 저희가 한번 확인해보겠습니다 고객님 구독을 취소를 언제 하셨는데요 오늘 됐어요 엄청 됐어 아 오래전에요 어 결제 되시는데 본인 확인을 위해서 고객님 성함과 연락처 확인 부탁드립니다 제 공주에 공 일 공 이 칠 육 번 팔 일 구 육 소중한 정보 확인 감사합니다 고객님 본인 맞으실까요 네네 고객님 정기구독 해지가 안되어 있는데요 금일 건 지금 취소는 가능은 하세요 그러면 해지를 어떻게 어떤 경로로 좀 정기구독 해지를 해주셨을까요 고객님 들어가셨는데 결제를 해지 완료까지 보셨어요 완료 됐죠 근데 이상하게 저 해지가 안되어있어서요 제가 지금 바로 정기구독 해지 처리도 가능은 하세요 고객님 해지처리 할까요 처리해주시고 그리고 바로 방금 결제해주는데 그것도 네 취소 가능합니다 아직 출고 전이라서요 고객님 금일 결제 건도 취소 완료되었습니다 감사합니다 어 아 네 해지되었어요 좋은 하루 보내세요 박혜영이었습니다
# ==========================================
# Audio :  /data3/stt_dataset/metaM/stt_inference_input_kenlm/103-1678167388.1973_stereo_mono.wav
# CTC :  네 여보세요 네 고객님 안녕하세요 저는 와이고 고객센터 정정하라고 합니다 네네 아 네 혹시 최주현 고객님 맞으실까요네 맞아요 아네 다름이 아니라 고 제품 수령 못하셨다고 하셔서 확인차 전화드렸는데 다시 다 되찮을 것네 다시 확인해봤더니 왔더라고요 아 수령하셨을까요 고객님네네네 그게 아직도 배송중으로 떠있어서 아 안 왔나 했었는데 왔더라고요 아 외고객님 정말 수령하셨다니까 너무 다행입니다네 불편드라 너무 죄송하고요 고객님니다네 혹시 추가적으로 다른 문의사항은 없으실까요네 네 시 안내주셔서 감사드립니다 와이교지 정정하였습니다네 감사합니다 감사합니다
# Kenlm :  네 여보세요 고객님 안녕하세요 저는 와이 고객센터 정정하라고 합니다 네 네 혹시 최주연 고객님 맞으실까요 다름이 아니라 제품 수령 못하셨다고 하셔서 확인차 전화드렸는데 다시 다시 확인해 봤더니 왔더라고요 수령하셨을까요 고객님 그게 아직도 배송 중으로 떠 있어서 왔나 했었는데 왔더라고요 아 고객님 정말 수령하셨다니까 너무 다행입니다 불편드려 너무 죄송하고요 고객님 시 추가적으로 다른 문의사항은 없으실까요 네 시 안내해주셔서 감사드립니다 와이지 정정하였습니다 감사합니다 감사합니다
# ==========================================
# Audio :  /data3/stt_dataset/metaM/stt_inference_input_kenlm/103-1677809403.994_stereo_mono.wav
# ==========================================
# Audio :  /data3/stt_dataset/metaM/stt_inference_input_kenlm/103-1679025688.1014_stereo_mono.wav
# CTC :  제가 온 경우 많이 드는 김 시간입니다 무엇을 도와드릴까요 아 네 제가 아까 물건 두 개를 주문했었는데요 아까 한 세 시간 전쯤에 그중에 하나를 제가 취소하고 싶은데 가능할까요 어 네 제가 확인해드리겠습니다 정보 확인 위해서 성함과 연락처 확인 부탁드립니다 네 김지혜구요네 공 일 공 네 구 일 사 공 네 육 이 육 삼이요아 네 김제고객님 확인 감사합니다네 어 지금 카시 마그네시마고 가으시냐 주문을 주셨는데요 네 너무 죄송하게도 아침에 일찍 주문해준신 거다 보니까 네 이쪽으로 넘어간 상태예요 고객님어 저가 열 두 시 출고 처리가 들어가서요  그러면 이미 집으로 이제려고 하는 거죠 어 늘 지금 출고 진행 중이고 고객님 아네 진행이 되시는 거라서 현재는 물류쪽으로 이 데이터가 넘어간 상태에서는 취소나 뭐 빼는 거나 그게 좀 어려우세요 괜히 그러면은 반품 처리는 할 수 있죠 도착한 다음에 음 도착한다에 반품하시거나 아니면 지금도 만약에 취소 원하시면 취소가 가능하신데 으로 넘어간 상태기 때문에 왕복 배송비를 제외하고 그 취소가 가능하셔서요 객님 아 괜찮아요 배송비 제외하고 취소할게요 아 그러시겠어요 고객님 안 먹을 거라서 버리는 것법  데 고객님 그러시면 일단 하나만 빼기는 어려워요 지금 전체 다시 물려있는 거다 보니까요 취소할려면 전체다 취소를 해야 되거든요 아 정말이요 하나씩 없어서 전체다 취소는 하고 어제 그 결제하셨던 거에서 왕복 배송비 왕복 배송비 육천 원 제외하고 환불되시구요 그리고 필요한 색상만 다시 주문을 주셔야 됩니다 고객님 아 왕복 배송비가 육천 원네거어요 한도가 삼천 원 부담 하셨습니까 왕복아 니거든요 아 네 그쵸 아 아 그러면은 아 제가 팔천 원을 내고 고개를 샀는데 그 좀 너무 그래서 일단은 저희가 원하시면 지금 취소도 가능은 하시는데 일단 물리로 넘어간 상태라 말씀드린 거 전소 하면 그  결제 셨던 거는 팔천 팔십 원인데 그래 환불은제 이천팔십 원을 받으시는 거예요 그쵸 그래서 네 아 그면 차감 네 어 네 알 알겠습니다 그냥 제가 다시 생각해보고 연락 나중에 오고 나서 그러면은 한 개만 반품  신청할 수 있어요   예약하고 나서 도착하시고 나서도 가능을 하세요 뜯지 않으시면 막상 배송비 제외 학고 환불되시신가 에이 고구는 무청에 것만습니다 아 네 알겠습니다 사합니다네 감사합니다네네 감사합니다 감사합니다
# Kenlm :  제가 온 경우가 많이 드는 김 시간입니다 무엇을 도와드릴까요 아 네 제가 아까 물건 두 개를 주문했었는데요 아까 한 세 시간 전쯤에 그중에 하나를 제가 취소하고 싶은데 가능할까요 어 네 제가 확인해드리겠습니다 정보 확인 위해서 성함과 연락처 확인 부탁드립니다 네 김지혜고요 공 일 공 구 사 공 육 이 육 삼이요 김제고객님 확인 감사합니다 지금 시 마그네시고 가시나 주문을 주셨는데요 너무 죄송하게도 아침에 주문해 주신 거다 보니까 이쪽으로 넘어간 상태예요 고객님 저 열 두 시 출고처리가 들어가서요 그러면 집으로 하는 거죠 지금 출고 진행 중이고 고객님 네 진행이 되시는 거라서 현재는 물류쪽으로 데이터가 넘어간 상태에서는 취소나 빼는 거나 그게 좀 어려우세요 괜히 그러면은 반품 처리는 할 수 있죠 도착한 다음에 도착한다에 반품하시거나 아니면 지금도 만약에 취소 원하시면 취소가 가능하신데 로 넘어간 상태기 때문에 왕복 배송비를 제외하고 취소가 가능하셨어요 아 괜찮아요 배송비 제외하고 취소할게요 그러시겠어요 고객님 안 먹을 거라서 버리는 것 고객님 그러시면 일단 하나만 빼기는 어려워요 지금 전체 지 물려있는 거다 보니까요 취소하려면 전체 취소를 해야 되거든요 아 정말요 하나 없어서 전체 취소를 하고 결제하셨던 거에서 왕복 배송비 왕복 배송비 육천 원 제외하고 환불되시구요 그리고 필요한 만 다시 주문을 주셔야 됩니다 고객님 왕복 배송비가 육천 원 한도가 삼천 원 부담하셨습니까 왕복 거든요 아 네 그쵸 그러면은 아 제가 팔천 원을 내고 고개를 샀는데 너무 그래서 일단은 저희가 원하시면 지금 취소도 가능은 하시는데 일단 물리로 넘어간 상태라 말씀드린 거 하면 그 결제했던 거는 팔천 팔십 원인데 그래 환불은 이천 팔백 원을 받으시는 거예요 그쵸 그래서 아 그러면 차감 네 알겠습니다 제가 다시 생각해보고 연락 나중에 오고 나서 그러면은 한 개만 반품 신청할 수 있어요 예약하고 나서 도착하시고 나서도 가능은 하세요 지 않으시면 배송비 제외하고 환불되고 다 네 알겠습니다 감사합니다 네 감사합니다 네 감사합니다 감사합니다
# ==========================================
# Audio :  /data3/stt_dataset/metaM/stt_inference_input_kenlm/103-1680584655.1421_stereo_mono.wav
# CTC :  최고운영  송시한입니다 무엇을 도와될까요 네 제가 저 회원 가입이 되있는데요 네 그근래 요즘 외국에 있어가지고 저  외국에 있는 동안 또 자동 그 세가지고 한번 왔더라고요 근데 그걸 다행히 찾줬는데 거기 수거하지도 않아가지고 이걸 정기 배송으로  해제하라고요  세요 고객님 죄합니다 연락처 말씀 부탁드리겠습니다 김태진이구요 공 일 공 오 공 팔 팔 팔 구 팔 네 소중한 정보 확인 감사합니다 마지막 결제 삼 월 이십 오 일 결제하신 거 아닌 제품들했어요 아 그 다행히네 그저 경비실에서 제가 좀 설던들어서 그 사무실로 전달 해줘가지고   터주면돼요 아다 고객님 혹시 정기구독은 그액 요청이신가요 정시 정기 요청이신가요  일단 해지해주세요 외굴 떨가지고 외국경절또 한국 핸드폰을 줄겨서 뭐 문자나 이런 것도 안 받거든요아 그래세요 고객님 주소지가 혹시 강남구 노래 오피텔 들  맞으시죠 고객님 아 오듯 오피텔도 빼아주고  애들네 알겠습니다  려주세요네 정기구독 해지 처리해드렸습니다 다른 사항  없습니다늘 뭐 자동으로 결제 되고 뭐 자동으로 배송하는 거는 없어지는 거죠 그렇습니다 한국으로 나서 필요할 던 제가 그 하면 되니까 네 고맙습니다  전화로 열심히 세했니  되었어요 네 감사합니다
# Kenlm :  최고 운영 입니다 무엇을 도와드릴까요 제가 저 회원가입이 되어 있는데요 그래 요즘 외국에 있어가지고 저 외국에 있는 동안 또 자동 해가지고 한번 왔더라고요 근데 그걸 다행히 줬는데 거기 수거하지도 않아가지고 정기 배송으로 해제하라구요 세 고객님 연락처 말씀 부탁드리겠습니다 김태진이고요 공 일 공 오 공 팔 팔 팔 구 팔 소중한 정보 확인 감사합니다 마지막 결제 삼 월 이십 오 일 결제하신 거 아닌 제품들어요 아 그 다행히 그 경비실에서 제가 설정 들어서 사무실로 전달 해줘가지고 쳐주면 돼요 고객님 정기구독은 요청이신가요 정기신가요 단 해지해주세요 떨어지고 외국도 한국 핸드폰을 줄여서 뭐 문자나 이런 것도 안 받거든요 그래서 고객님 주소지가 혹시 강남구 노래 오피스 맞으시죠 고객님 오피도 빼주고 알겠습니다 주세요 정기구독 해지 처리해드렸습니다 다른 사항 없습니다 뭐 자동으로 결제되고 자동으로 배송하는 건 없어지는 거죠 그렇습니다 한국 서 필요할 때 제가 그 하면 되니까 고맙습니다 전화 열심히 사니요 네 감사합니다
# ==========================================
# Audio :  /data3/stt_dataset/metaM/stt_inference_input_kenlm/103-1678151985.449_stereo_mono.wav
# CTC :  제가 변경 아이들리 이미지입니다 무엇을 도와드릴까요 어 여기서 어 주문을 들어왔는데 네 개정료 배정 연동 로그인을 하라고 해가지고 네 했는데 비밀번호가 계속 맞나요 어 고객님 혹시 카톡으로 십 대 로그인하신 게 맞으세요  네 고객님 혹시 임시일번 괜찮으시다면 제가 문자로 발아 인시일번 저희가 이메일 주소랑 휴대폰으로 저희가 모두 다 발송해드릴게요  번호는 보내주세요 메일이랑 휴대폰 번호 모두 다 발송해드렸구요 고객님 그 만들어왔는데 저희가 지금 발송했어요 그러면 삼십 초에서 일 분 이후에 일 분 이후에 고객님 수신이 될 거구요 고객님  어 실례지만 고객님 성함이랑 연락처번호가 몇 번이세요 이름이 구문서 네 핸드번 공 일 공 삼 사 오 육 네 오 점가 번호 아 네 고객님 소전 정보 확인 감사드립니다 구사 고객님 본인 맞으신 거죠 음 네 고객님 발송드렸구요 그 임시불간 받으시는 걸로 로그인하신 후에 고객님 이제 개인정보이기 때문에 즉시 변경 부탁드리겠습니다 고객님 혹시 또 다른 문의사항은 없으실까요  왔네네 감사합니다
# Kenlm :  제가 변경 아이들리 이미지입니다 무엇을 도와드릴까요 여기서 주문을 들어왔는데 배송 배정 연동 로그인을 하라고 해가지고 했는데 비밀번호가 계속 맞나요 어 고객님 혹시 카톡으로 십 대 로그인하신 게 맞으세요 고객님 혹시 임시일 괜찮으시다면 제가 문자로 번 저희가 이메일 주소랑 휴대폰으로 저희가 모두 다 발송해드릴게요 번호는 보내주세요 메일이랑 휴대폰 번호 모두 다 발송해드렸구요 고객님 만들어왔는데 저희가 지금 발송했어요 그러면 삼십 초에서 일 분 일 분 이후에 고객님 수신이 될 거고요 고객님 실례지만 고객님 성함이랑 연락처 번호가 몇 번이세요 이름 구문 네 핸드폰 공 일 공 삼 사 오 육 오 삼 번 아 네 고객님 소전 정보 확인 감사드립니다 서 고객님 본인 맞으신 거죠 네 고객님 발송드렸구요 그 인시간 받으시는 걸로 로그인하신 후에 고객님 개인정보이기 때문에 즉시 변경 부탁드리겠습니다 고객님 혹시 또 다른 문의사항은 없으실까요 네 감사합니다
# ==========================================
# Audio :  /data3/stt_dataset/metaM/stt_inference_input_kenlm/103-1678952276.2388_stereo_mono.wav
# CTC :  아 네 안녕하세요 와이파백 문객센터입니다 네 아까 말씀하셨던 두 가지 상품 관련해서 저희 배송비 왕복 배송도 제외하고 각각  상품으로 환불 드렸고요 네 그리고 아까 교통은 앞으로 해지하신다고 말씀해주셨나요 고객님 네 네 구독 해지 처리까지 해드렸습니다네네어 고객님 그러시면 이제 그 주소지에 주소 변경하셔서 아까 주소지가 가게일인가 그러셨는데에 그이 안되진 것 같아서 앞으로 주문하시지 않고 주소지 좀 변경 좀 부탁드리겠습니다 아 제가 직접 이렇게 하면 되는 거예요 예 그냥 그 들어가셔서 온라인으로 들어가셔서 정보 변경해서 수정해주시면 됩니다 아 반복이 된 거예요 어 지금 제가 환불 조치했는데요 고님 카드 결제하다 보니까 저는 지금 취소했지만 고객 카드 환불되는 거라 되면 카드사에 따라서 며칠 걸리실 겁니다 아 번거롭게 죄송합니다 아 아닙니다 고객님 일단 나머지는 저희 어쨌든 그 주소는 좀회하셔서 갈 거구요 네네 그리고 창후에는 주문하실 때 주소 정확한 변 기 부탁드리겠습니다 고객님 다시 주문하기 했다 죄송합니다 감사합니다 좋은 하루 되세요
# Kenlm :  아 네 안녕하세요 와이파이 문센터입니다 네 아까 말씀하셨던 두 가지 상품 관련해서 저희 배송비 왕복 배송비 제외하고 각각 상품으로 환불 드렸고요 그리고 아까 보통은 앞으로 해지하신다고 말씀해주셨나요 고객님 구독 해지처리까지 해드렸습니다 고객님 그러시면 이제 그 주소지에 주소 변경하셔서 아까 주소지가 가게인가 그러셨는데 안되신 것 같아서 앞으로 주문하지 않고 주소지 좀 변경 좀 부탁드리겠습니다 제가 직접 이렇게 하면 되는 거예요 예 그냥 들어가셔서 온라인으로 들어가셔서 정보 변경해서 수정해 주시면 됩니다 아 반복이 된 거예요 지금 제가 환불 조치했는데 고 카드 결제하다 보니까 저는 지금 취소했지만 고객 카드 환불되는 거 되 카드사에 따라서 며칠 걸리실 겁니다 번거롭게 죄송합니다 아 아닙니다 고객님 일단 나머지는 저희 어쨌든 그 주소 하셔서 갈 거구요 네 그 후에는 주문하실 때 주소 정확한 부탁드리겠습니다 고객님 다시 주문하게 다 죄송합니다 감사합니다 좋은 하루 되세요
# ==========================================
